# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('housing_price_dataset.csv')
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt   Price
# 0            2126         4          1        Rural       1969  215355
# 1            2459         3          2        Rural       1980  195014
# 2            1860         2          1       Suburb       1970  306891
# 3            2294         2          1        Urban       1996  206787
# 4            2130         5          2       Suburb       2001  272436
# ...           ...       ...        ...          ...        ...     ...
# 49995        1282         5          3        Rural       1975  100081
# 49996        2854         2          2       Suburb       1988  374508
# 49997        2979         5          3       Suburb       1962  384111
# 49998        2596         5          2        Rural       1984  380513
# 49999        1572         5          3        Rural       2011  221619
#
# [50000 rows x 6 columns]

# %%
df.dtypes
# Out:
# SquareFeet       int64
# Bedrooms         int64
# Bathrooms        int64
# Neighborhood    object
# YearBuilt        int64
# Price            int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# SquareFeet      0
# Bedrooms        0
# Bathrooms       0
# Neighborhood    0
# YearBuilt       0
# Price           0
# dtype: int64

# %%
df.isna().sum()
# Out:
# SquareFeet      0
# Bedrooms        0
# Bathrooms       0
# Neighborhood    0
# YearBuilt       0
# Price           0
# dtype: int64

# %%
for i in df.columns:
    if len(df[i].unique())==1:
        print(i)

# %%
df.dropna()
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt   Price
# 0            2126         4          1        Rural       1969  215355
# 1            2459         3          2        Rural       1980  195014
# 2            1860         2          1       Suburb       1970  306891
# 3            2294         2          1        Urban       1996  206787
# 4            2130         5          2       Suburb       2001  272436
# ...           ...       ...        ...          ...        ...     ...
# 49995        1282         5          3        Rural       1975  100081
# 49996        2854         2          2       Suburb       1988  374508
# 49997        2979         5          3       Suburb       1962  384111
# 49998        2596         5          2        Rural       1984  380513
# 49999        1572         5          3        Rural       2011  221619
#
# [50000 rows x 6 columns]

# %%
df.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325600
# std      575.513241      1.116326      0.815851     20.719377   76141.842789
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.000000
# 25%     1513.000000      3.000000      1.000000   1967.000000  169956.000000
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.000000
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.500000
# max     2999.000000      5.000000      3.000000   2021.000000  492195.000000

# %%
x = df['SquareFeet']
y = df['Price']
plt.bar(x, y)
plt.title('Barplot')
plt.xlabel('Square Feet')
plt.show()

# %%
plt.hist(x)
plt.title('Histogram')
plt.xlabel('Square Feet')
plt.ylabel('Square Feet')
plt.show()

# %%
plt.scatter(x.head(2500), y.head(2500))
plt.title('Scatter Plot First 2500')
plt.xlabel('Square Feet')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(x.tail(2500), y.tail(2500))
plt.title('Scatter Plot Last 2500')
plt.xlabel('Square Feet')
plt.ylabel('Price')
plt.show()
